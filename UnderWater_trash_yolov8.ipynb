# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ultralytics -q

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8m.pt")

# %%
# !touch data.yaml

# %%
model.train(data = "/content/drive/MyDrive/yolov8/Underwater Trash Detection.v5-dataset_v3_2022-04-21-9-00pm.yolov8/data.yaml", epochs = 15)
# Out:
# Ultralytics YOLOv8.0.136 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
infer = YOLO("/content/runs/detect/train/weights/best.pt")

# %%
infer.predict("/content/drive/MyDrive/yolov8/Underwater Trash Detection.v5-dataset_v3_2022-04-21-9-00pm.yolov8/test/images", save = True, save_txt = True)
# Out:
# image 1/18 /content/drive/MyDrive/yolov8/Underwater Trash Detection.v5-dataset_v3_2022-04-21-9-00pm.yolov8/test/images/12_jpg.rf.54bbff9e399d905c856ad653a1fad154.jpg: 640x640 (no detections), 36.4ms
# image 2/18 /content/drive/MyDrive/yolov8/Underwater Trash Detection.v5-dataset_v3_2022-04-21-9-00pm.yolov8/test/images/6_jpg.rf.e6c5bdc17c4cb3d61128ab11249661e5.jpg: 640x640 1 plastic-bag, 35.1ms
# image 3/18 /content/drive/MyDrive/yolov8/Underwater Trash Detection.v5-dataset_v3_2022-04-21-9-00pm.yolov8/test/images/70_jpg.rf.46cbbad4c20e7d5f2ab72bee07af21af.jpg: 640x640 1 bottle, 1 waste, 31.1ms
# image 4/18 /content/drive/MyDrive/yolov8/Underwater Trash Detection.v5-dataset_v3_2022-04-21-9-00pm.yolov8/test/images/78_jpg.rf.b9539d3ed1b12627f94f952623e706e0.jpg: 640x640 (no detections), 30.6ms
# ...

# %%
# !yolo detect predict model = "/content/runs/detect/train/weights/best.pt" source = "/content/drive/MyDrive/videoblocks-63bfe312270e3f1671aa7150_bvltgytci__1dc09d95a9958e08dd855cfd90af6eb9__P360.mp4"
# Out:
# Ultralytics YOLOv8.0.136 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25842076 parameters, 0 gradients
#
# video 1/1 (1/227) /content/drive/MyDrive/videoblocks-63bfe312270e3f1671aa7150_bvltgytci__1dc09d95a9958e08dd855cfd90af6eb9__P360.mp4: 384x640 (no detections), 68.1ms
# video 1/1 (2/227) /content/drive/MyDrive/videoblocks-63bfe312270e3f1671aa7150_bvltgytci__1dc09d95a9958e08dd855cfd90af6eb9__P360.mp4: 384x640 (no detections), 25.2ms
# video 1/1 (3/227) /content/drive/MyDrive/videoblocks-63bfe312270e3f1671aa7150_bvltgytci__1dc09d95a9958e08dd855cfd90af6eb9__P360.mp4: 384x640 (no detections), 25.2ms
# video 1/1 (4/227) /content/drive/MyDrive/videoblocks-63bfe312270e3f1671aa7150_bvltgytci__1dc09d95a9958e08dd855cfd90af6eb9__P360.mp4: 384x640 (no detections), 25.2ms
# video 1/1 (5/227) /content/drive/MyDrive/videoblocks-63bfe312270e3f1671aa7150_bvltgytci__1dc09d95a9958e08dd855cfd90af6eb9__P360.mp4: 384x640 (no detections), 25.2ms
# ...

# %%
# !ffmpeg -i {"/content/runs/detect/predict8/videoblocks-63bfe312270e3f1671aa7150_bvltgytci__1dc09d95a9958e08dd855cfd90af6eb9__P360.avi"} -vcodec libx265 {"underground_3.mp4"}
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...
